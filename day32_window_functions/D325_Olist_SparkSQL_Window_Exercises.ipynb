# %% [markdown]
# # D325 — Olist Spark SQL Window Exercises
#
# Adapted from unresolved D173 for Spark SQL 3.5.9.

# %% [markdown]
# ## Lab rules
#
# - Use Apache Spark **3.5.9**, `spark.sql(...)`, DataFrames, and the Spark session catalog only.
# - Source tables are in `olist_silver`; do not read CSV again in analytical notebooks.
# - Use CTEs and windows only when the exercise permits or requires them.
# - State the grain of every intermediate and final result.
# - Prevent multiplication when joining two one-to-many datasets such as items and payments.
# - Round displayed currency to two decimals, but do not round intermediate calculations.
# - Every answer cell is intentionally empty. This notebook contains no solution SQL.
# - Catalog metadata persists in local embedded Derby; use the same `SPARK_CATALOG_DIR` in D322–D326.
# - Only one active Spark driver may use this catalog. Stop the prior notebook's Spark session first.

# %%
import os
import socket

from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql.types import IntegerType, StringType, StructField, StructType

master_url = os.environ.get(
    "SPARK_MASTER",
    f"spark://{socket.gethostname()}:7077",
)

spark = (
    SparkSession.builder
    .appName("D32-Spark-SQL-Window-Functions")
    .master(master_url)
    .getOrCreate()
)
spark.sparkContext.setLogLevel("WARN")
print("Spark version:", spark.version)
print("Master:", spark.sparkContext.master)

# %%
spark.sql("USE olist_silver")

# %% [markdown]
# ## Exercise 1: Rank sellers within state
#
# Aggregate revenue by seller, join location, then calculate row number, rank, and dense rank within state. Use seller ID as tie-breaker only for row number.
#
# **Must use:** CTE, ROW_NUMBER, RANK, DENSE_RANK
#
# **Expected result:** state, seller, revenue, three positions.

# %%
# TODO: Write and execute your Spark SQL answer.
# result_df = spark.sql("""
# ...
# """)
# result_df.show(truncate=False)

# %% [markdown]
# ## Exercise 2: Previous order payment
#
# Aggregate payments per order; join orders/customers and compare each buyer order with its previous payment.
#
# **Must use:** CTE, LAG, deterministic ordering
#
# **Expected result:** current/previous payment and change.

# %%
# TODO: Write and execute your Spark SQL answer.
# result_df = spark.sql("""
# ...
# """)
# result_df.show(truncate=False)

# %% [markdown]
# ## Exercise 3: Next purchase
#
# Return each buyer order, next purchase timestamp, and days until it using Spark SQL `datediff`.
#
# **Must use:** LEAD, PARTITION BY
#
# **Expected result:** last buyer order has null next values.

# %%
# TODO: Write and execute your Spark SQL answer.
# result_df = spark.sql("""
# ...
# """)
# result_df.show(truncate=False)

# %% [markdown]
# ## Exercise 4: First and last purchase
#
# Label every buyer order with first and last purchase timestamps.
#
# **Must use:** FIRST_VALUE, LAST_VALUE, full ROWS frame
#
# **Expected result:** constant boundary timestamps per buyer.

# %%
# TODO: Write and execute your Spark SQL answer.
# result_df = spark.sql("""
# ...
# """)
# result_df.show(truncate=False)

# %% [markdown]
# ## Exercise 5: Seller monthly running revenue
#
# Aggregate seller revenue by purchase year/month, create a sortable month key, and calculate cumulative revenue.
#
# **Must use:** CTE, SUM OVER, unbounded-preceding frame
#
# **Expected result:** seller-month revenue and nondecreasing running value.

# %%
# TODO: Write and execute your Spark SQL answer.
# result_df = spark.sql("""
# ...
# """)
# result_df.show(truncate=False)

# %% [markdown]
# ## Exercise 6: Three-row seller moving average
#
# On seller-month aggregates, average current and two preceding available rows. Explain why rows may not be consecutive calendar months.
#
# **Must use:** AVG OVER, ROWS BETWEEN 2 PRECEDING AND CURRENT ROW
#
# **Expected result:** monthly and moving revenue.

# %%
# TODO: Write and execute your Spark SQL answer.
# result_df = spark.sql("""
# ...
# """)
# result_df.show(truncate=False)

# %% [markdown]
# ## Exercise 7: Centered review window
#
# First ensure seller/order appears once; order reviews per seller and average previous/current/next score.
#
# **Must use:** deduplication CTE, ROWS BETWEEN 1 PRECEDING AND 1 FOLLOWING
#
# **Expected result:** centered score average.

# %%
# TODO: Write and execute your Spark SQL answer.
# result_df = spark.sql("""
# ...
# """)
# result_df.show(truncate=False)

# %% [markdown]
# ## Exercise 8: First and last item price
#
# For multi-item orders, retain item rows and label first/last item price using item sequence.
#
# **Must use:** CTE, FIRST_VALUE, LAST_VALUE, full frame
#
# **Expected result:** constant boundaries per order.

# %%
# TODO: Write and execute your Spark SQL answer.
# result_df = spark.sql("""
# ...
# """)
# result_df.show(truncate=False)

# %% [markdown]
# ## Exercise 9: Category month-over-month change
#
# Using native category, aggregate monthly revenue; use LAG for previous active month and calculate absolute/percent change with `nullif`.
#
# **Must use:** CTE, LAG, NULLIF
#
# **Expected result:** category/month current, previous, and changes.

# %%
# TODO: Write and execute your Spark SQL answer.
# result_df = spark.sql("""
# ...
# """)
# result_df.show(truncate=False)

# %% [markdown]
# ## Exercise 10: Top three products per category
#
# Aggregate product revenue by native category; rank with dense rank, capture leader revenue, keep ranks 1–3, and calculate leader gap.
#
# **Must use:** chained CTEs, DENSE_RANK, FIRST_VALUE, full frame
#
# **Expected result:** category/product ranking and gap.

# %%
# TODO: Write and execute your Spark SQL answer.
# result_df = spark.sql("""
# ...
# """)
# result_df.show(truncate=False)
