# %% [markdown]
# # D324 — Olist Spark SQL CTE Exercises
#
# Adapted from the unresolved D172 seller exercises. Every answer must use one or more CTEs and no window functions.

# %% [markdown]
# ## Lab rules
#
# - Use Apache Spark **3.5.9**, `spark.sql(...)`, DataFrames, and the Spark session catalog only.
# - Source tables are in `olist_silver`; do not read CSV again in analytical notebooks.
# - Use CTEs and windows only when the exercise permits or requires them.
# - State the grain of every intermediate and final result.
# - Prevent multiplication when joining two one-to-many datasets such as items and payments.
# - Round displayed currency to two decimals, but do not round intermediate calculations.
# - Every answer cell is intentionally empty. This notebook contains no solution SQL.
# - Catalog metadata persists in local embedded Derby; use the same `SPARK_CATALOG_DIR` in D322–D326.
# - Only one active Spark driver may use this catalog. Stop the prior notebook's Spark session first.

# %%
import os
import socket

from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql.types import IntegerType, StringType, StructField, StructType

master_url = os.environ.get(
    "SPARK_MASTER",
    f"spark://{socket.gethostname()}:7077",
)

spark = (
    SparkSession.builder
    .appName("D32-Spark-SQL-Window-Functions")
    .master(master_url)
    .getOrCreate()
)
spark.sparkContext.setLogLevel("WARN")
print("Spark version:", spark.version)
print("Master:", spark.sparkContext.master)

# %%
spark.sql("USE olist_silver")

# %% [markdown]
# ## Exercise 1: High-revenue sellers
#
# Create `seller_sales` with item count, distinct orders, and revenue; filter revenue at least 100,000 outside.
#
# **Must use:** aggregate CTE and outer WHERE
#
# **Expected result:** seller metrics ordered by revenue.

# %%
# TODO: Write and execute your Spark SQL answer.
# result_df = spark.sql("""
# ...
# """)
# result_df.show(truncate=False)

# %% [markdown]
# ## Exercise 2: Seller performance with location
#
# Aggregate seller sales in a CTE, join sellers outside, return top 15.
#
# **Must use:** aggregate CTE, outer JOIN and LIMIT
#
# **Expected result:** seller ID, city, state, items, revenue.

# %%
# TODO: Write and execute your Spark SQL answer.
# result_df = spark.sql("""
# ...
# """)
# result_df.show(truncate=False)

# %% [markdown]
# ## Exercise 3: Delivered sales by seller
#
# Create delivered item detail in a CTE; aggregate outside and retain at least 100 delivered orders.
#
# **Must use:** JOIN/WHERE inside; GROUP BY/HAVING outside
#
# **Expected result:** delivered orders, items, revenue by seller.

# %%
# TODO: Write and execute your Spark SQL answer.
# result_df = spark.sql("""
# ...
# """)
# result_df.show(truncate=False)

# %% [markdown]
# ## Exercise 4: Seller versus state totals
#
# Build seller sales with state, then state sales from it; join both. Keep sellers with at least 100,000 revenue.
#
# **Must use:** two chained CTEs
#
# **Expected result:** seller and state revenue.

# %%
# TODO: Write and execute your Spark SQL answer.
# result_df = spark.sql("""
# ...
# """)
# result_df.show(truncate=False)

# %% [markdown]
# ## Exercise 5: Seller category diversity
#
# Within a CTE join items and products; use native non-null product category. Aggregate distinct categories, items, and revenue, then retain sellers with at least 20 categories.
#
# **Must use:** CTE, COUNT(DISTINCT), outer filter
#
# **Expected result:** seller diversity metrics.

# %%
# TODO: Write and execute your Spark SQL answer.
# result_df = spark.sql("""
# ...
# """)
# result_df.show(truncate=False)

# %% [markdown]
# ## Exercise 6: Seller review quality
#
# Aggregate distinct reviewed orders and score metrics by seller, then retain at least 100 reviews and average at least 4.0.
#
# **Must use:** aggregate CTE and outer WHERE
#
# **Expected result:** seller review metrics.

# %%
# TODO: Write and execute your Spark SQL answer.
# result_df = spark.sql("""
# ...
# """)
# result_df.show(truncate=False)

# %% [markdown]
# ## Exercise 7: Local versus interstate sales
#
# Create seller/order/customer detail, then conditionally aggregate same-state and different-state revenue; keep sellers with at least 100 orders.
#
# **Must use:** four-table CTE, CASE, SUM, HAVING
#
# **Expected result:** seller, order count, two revenue measures.

# %%
# TODO: Write and execute your Spark SQL answer.
# result_df = spark.sql("""
# ...
# """)
# result_df.show(truncate=False)

# %% [markdown]
# ## Exercise 8: Monthly seller activity in 2018
#
# Filter orders with a half-open 2018 timestamp range in a CTE; outside, group by seller and purchase year/month partition columns; keep at least 50 orders.
#
# **Must use:** date-filtered CTE, aggregates, HAVING
#
# **Expected result:** seller, purchase year/month, orders, revenue.

# %%
# TODO: Write and execute your Spark SQL answer.
# result_df = spark.sql("""
# ...
# """)
# result_df.show(truncate=False)

# %% [markdown]
# ## Exercise 9: Above-average seller revenue
#
# Use chained CTEs for seller revenue, overall average, and comparison; no subquery in final WHERE.
#
# **Must use:** at least two aggregation levels
#
# **Expected result:** seller revenue and displayed overall average.

# %%
# TODO: Write and execute your Spark SQL answer.
# result_df = spark.sql("""
# ...
# """)
# result_df.show(truncate=False)

# %% [markdown]
# ## Exercise 10: Seller dashboard
#
# Aggregate sales and reviews in separate CTEs before joining sellers. Keep at least 200 orders and 100 reviewed orders; return top 20 by revenue.
#
# **Must use:** multiple independent CTEs and outer joins/filter
#
# **Expected result:** location, sales, freight, and review metrics.

# %%
# TODO: Write and execute your Spark SQL answer.
# result_df = spark.sql("""
# ...
# """)
# result_df.show(truncate=False)
