# %% [markdown]
# # D323 — Olist Spark SQL Analytical Exercises
#
# Adapted from the unresolved D170 exercises for Silver Parquet tables.

# %% [markdown]
# ## Lab rules
#
# - Use Apache Spark **3.5.9**, `spark.sql(...)`, DataFrames, and the Spark session catalog only.
# - Source tables are in `olist_silver`; do not read CSV again in analytical notebooks.
# - Use CTEs and windows only when the exercise permits or requires them.
# - State the grain of every intermediate and final result.
# - Prevent multiplication when joining two one-to-many datasets such as items and payments.
# - Round displayed currency to two decimals, but do not round intermediate calculations.
# - Every answer cell is intentionally empty. This notebook contains no solution SQL.
# - Catalog metadata persists in local embedded Derby; use the same `SPARK_CATALOG_DIR` in D322–D326.
# - Only one active Spark driver may use this catalog. Stop the prior notebook's Spark session first.

# %%
import os
import socket

from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql.types import IntegerType, StringType, StructField, StructType

master_url = os.environ.get(
    "SPARK_MASTER",
    f"spark://{socket.gethostname()}:7077",
)

spark = (
    SparkSession.builder
    .appName("D32-Spark-SQL-Window-Functions")
    .master(master_url)
    .getOrCreate()
)
spark.sparkContext.setLogLevel("WARN")
print("Spark version:", spark.version)
print("Master:", spark.sparkContext.master)

# %%
spark.sql("USE olist_silver")
spark.sql("SHOW TABLES").show(truncate=False)

# %% [markdown]
# ## Exercise 1: Customer count by state
#
# Using customers, return each state and its customer-record count, largest first.
#
# **Must use:** COUNT, GROUP BY, ORDER BY
#
# **Expected result:** `customer_state`, `customer_count`; one row per state.

# %%
# TODO: Write and execute your Spark SQL answer.
# result_df = spark.sql("""
# ...
# """)
# result_df.show(truncate=False)

# %% [markdown]
# ## Exercise 2: Top 10 spending customers
#
# Join customers, orders, and payments. Return the ten unique buyers with greatest total payments and their distinct order count.
#
# **Must use:** two INNER JOINs, COUNT(DISTINCT), SUM, GROUP BY, ORDER BY, LIMIT
#
# **Expected result:** 10 rows: `customer_unique_id`, `order_count`, `total_spent`.

# %%
# TODO: Write and execute your Spark SQL answer.
# result_df = spark.sql("""
# ...
# """)
# result_df.show(truncate=False)

# %% [markdown]
# ## Exercise 3: Payment summary by type
#
# Exclude `not_defined`; summarize count, min, max, average, and total payment by type.
#
# **Must use:** WHERE and aggregate functions
#
# **Expected result:** one row per valid payment type, ordered by total descending.

# %%
# TODO: Write and execute your Spark SQL answer.
# result_df = spark.sql("""
# ...
# """)
# result_df.show(truncate=False)

# %% [markdown]
# ## Exercise 4: Large delivered orders
#
# Join orders and items; for delivered orders calculate item count, item total, freight total, and combined order value. Keep orders with at least five items.
#
# **Must use:** JOIN, WHERE, GROUP BY, HAVING, LIMIT
#
# **Expected result:** top 10 ordered by item count then order value descending.

# %%
# TODO: Write and execute your Spark SQL answer.
# result_df = spark.sql("""
# ...
# """)
# result_df.show(truncate=False)

# %% [markdown]
# ## Exercise 5: High-volume seller states
#
# Summarize seller states by distinct sellers, items sold, and item revenue. Keep states with at least 100 sellers and revenue above 1,000,000.
#
# **Must use:** JOIN, COUNT(DISTINCT), GROUP BY, HAVING
#
# **Expected result:** `seller_state`, `seller_count`, `items_sold`, `item_revenue`.

# %%
# TODO: Write and execute your Spark SQL answer.
# result_df = spark.sql("""
# ...
# """)
# result_df.show(truncate=False)

# %% [markdown]
# ## Exercise 6: Best-selling product categories
#
# Join items to products and use native `product_category_name` (translation was intentionally omitted). Exclude null categories and return top ten by revenue with distinct orders, item count, average price, and revenue.
#
# **Must use:** JOIN, WHERE, aggregates, LIMIT
#
# **Expected result:** 10 category rows, revenue descending.

# %%
# TODO: Write and execute your Spark SQL answer.
# result_df = spark.sql("""
# ...
# """)
# result_df.show(truncate=False)

# %% [markdown]
# ## Exercise 7: Review score by order status
#
# Join orders and reviews; calculate review count, min, max, and average score per status; keep statuses with at least ten reviews.
#
# **Must use:** JOIN, GROUP BY, HAVING
#
# **Expected result:** one row per qualifying status.

# %%
# TODO: Write and execute your Spark SQL answer.
# result_df = spark.sql("""
# ...
# """)
# result_df.show(truncate=False)

# %% [markdown]
# ## Exercise 8: Freight by customer state
#
# For delivered orders, calculate item count and min/max/average/total freight per customer state.
#
# **Must use:** two JOINs, WHERE, aggregates
#
# **Expected result:** state rows ordered by total freight descending.

# %%
# TODO: Write and execute your Spark SQL answer.
# result_df = spark.sql("""
# ...
# """)
# result_df.show(truncate=False)

# %% [markdown]
# ## Exercise 9: Strong delivered-order cities
#
# Group delivered orders by customer state and city; retain groups with at least 500 distinct orders.
#
# **Must use:** JOIN, WHERE, COUNT(DISTINCT), HAVING
#
# **Expected result:** state, city, delivered order count.

# %%
# TODO: Write and execute your Spark SQL answer.
# result_df = spark.sql("""
# ...
# """)
# result_df.show(truncate=False)

# %% [markdown]
# ## Exercise 10: Premium-item categories
#
# Using native product category, keep items priced at least 500; summarize prices and revenue, retaining categories with at least 20 premium items.
#
# **Must use:** JOIN, WHERE, GROUP BY, HAVING
#
# **Expected result:** category and premium-item metrics.

# %%
# TODO: Write and execute your Spark SQL answer.
# result_df = spark.sql("""
# ...
# """)
# result_df.show(truncate=False)

# %% [markdown]
# ## Exercise 11: Credit-card installments
#
# For credit-card payments with installments 1–12, summarize payment metrics and retain groups with at least 100 payments.
#
# **Must use:** BETWEEN, aggregates, HAVING
#
# **Expected result:** one row per qualifying installment count.

# %%
# TODO: Write and execute your Spark SQL answer.
# result_df = spark.sql("""
# ...
# """)
# result_df.show(truncate=False)

# %% [markdown]
# ## Exercise 12: Same-state commerce
#
# Join customers, orders, items, and sellers; keep seller state equal to customer state. Summarize orders, sellers, items, average price, and revenue; retain states with at least 500 orders.
#
# **Must use:** three JOINs, column comparison, aggregates, HAVING
#
# **Expected result:** one row per qualifying shared state.

# %%
# TODO: Write and execute your Spark SQL answer.
# result_df = spark.sql("""
# ...
# """)
# result_df.show(truncate=False)

# %% [markdown]
# ## Persist one analytical result
#
# Choose one result with a reusable business grain. Write it as Parquet to an explicit HDFS path, then register/read it through the Spark catalog. Record row count and location. This is separate from the MySQL task in D326.

# %%
# TODO: Write one result to HDFS as Parquet and verify it.
