# %% [markdown]
# # D251 — Olist Core Analytics in HiveSQL: Student Exercises
#
# Solve business questions with joins, filters, aggregation, `HAVING`, sorting, and limits. These exercises assume the `olist_hive` tables prepared in D250. Do not use CTEs, window functions, or subqueries unless an exercise explicitly permits them.

# %% [markdown]
# ## Lab conventions
#
# - Run this notebook from Jupyter in Ubuntu/WSL with HDFS, YARN, the Hive metastore, and HiveServer2 running.
# - Source CSVs are expected at `/mnt/c/data/olist`. Change `OLIST_SOURCE` if your copy is elsewhere.
# - Use database `olist_hive`. Raw external tables should be named after the MySQL tables: `olist_customers`, `olist_orders`, `olist_order_items`, `olist_order_payments`, `olist_order_reviews`, `olist_products`, `olist_sellers`, `olist_geolocation`, and `product_category_translation`.
# - These are learner exercises. TODO cells intentionally contain no completed answer.

# %% [markdown]
# ## MySQL → HiveSQL reminders
#
# | MySQL habit | HiveSQL approach in this lab |
# |---|---|
# | `LIMIT offset, count` | use `LIMIT count`; use `ROW_NUMBER()` when paging is genuinely required |
# | `IFNULL(x, y)` | prefer standard `COALESCE(x, y)` |
# | `DATEDIFF(end, start)` | same two-argument order in Hive; result is whole days |
# | `DATE_FORMAT(ts, '%Y-%m')` | use `date_format(ts, 'yyyy-MM')` |
# | `YEAR(ts)` / `MONTH(ts)` | `year(ts)` / `month(ts)` are available |
# | `GROUP_CONCAT` | use `concat_ws(',', collect_list(...))` when appropriate |
# | backtick-heavy identifiers | use simple lowercase snake_case names; backticks are rarely needed here |
# | primary keys, foreign keys, and row indexes | Hive generally does not enforce relational keys; performance comes from file format, partitions, statistics, pruning, and execution settings |
# | `EXPLAIN ANALYZE` | use `EXPLAIN`, `EXPLAIN FORMATTED`, and runtime/Tez or YARN evidence available in your installation |
#
# Hive aliases usually cannot be reused by another expression in the same `SELECT`. Put the first calculation in a CTE/subquery. Always make window ordering deterministic by adding an ID as a tie-breaker.

# %% [markdown]
# ## Rules
#
# - Round displayed monetary results to two decimals.
# - Use `COUNT(DISTINCT ...)` at the correct business grain.
# - Add a stable tie-breaker to ordered results.
# - Before each query, write one sentence stating what one output row represents.
# - Use `EXPLAIN` on at least two multi-table queries and identify scans, joins, and aggregations.

# %% [markdown]
# ## Exercise 1 — Customer count by state
#
# Return every customer state and its customer-record count, largest first. Expected shape: `customer_state`, `customer_count`.
#
# **Tip:** `customer_id` is order-specific; this question asks for records, not unique people.

# %%
# %%bash
# # TODO: Write and run your solution here.
# # beeline -u 'jdbc:hive2://localhost:10000/olist_hive' -n "$USER" --silent=true -e "
# #   -- your HiveQL here
# # "

# %% [markdown]
# ## Exercise 2 — Top 10 spending customers
#
# Join customers, orders, and payments. Return the 10 `customer_unique_id` values with the largest total payment, plus distinct order count. Expected shape: `customer_unique_id`, `order_count`, `total_spent`.
#
# **Tip:** Aggregate at customer grain and use a deterministic secondary sort.

# %%
# %%bash
# # TODO: Write and run your solution here.
# # beeline -u 'jdbc:hive2://localhost:10000/olist_hive' -n "$USER" --silent=true -e "
# #   -- your HiveQL here
# # "

# %% [markdown]
# ## Exercise 3 — Payment summary by type
#
# Exclude `not_defined`. For each payment type calculate row count, minimum, maximum, average, and total payment value.
#
# **Tip:** If raw measures are strings, cast once through the curated table or an allowed view before aggregation.

# %%
# %%bash
# # TODO: Write and run your solution here.
# # beeline -u 'jdbc:hive2://localhost:10000/olist_hive' -n "$USER" --silent=true -e "
# #   -- your HiveQL here
# # "

# %% [markdown]
# ## Exercise 4 — Monthly delivered-order trend
#
# For delivered orders, return purchase month, distinct order count, distinct buyers, and total payment. Sort chronologically.
#
# **Tip:** Hive uses `date_format(timestamp_col, 'yyyy-MM')`, not MySQL `%Y-%m`. Aggregate payments to order grain before joining if needed to avoid fan-out.

# %%
# %%bash
# # TODO: Write and run your solution here.
# # beeline -u 'jdbc:hive2://localhost:10000/olist_hive' -n "$USER" --silent=true -e "
# #   -- your HiveQL here
# # "

# %% [markdown]
# ## Exercise 5 — Top product categories by item revenue
#
# Join items, products, and translation. Return the top 15 English categories with item count, distinct order count, and item revenue.
#
# **Tip:** Keep untranslated or null categories visible with `COALESCE` unless the requirement says to discard them.

# %%
# %%bash
# # TODO: Write and run your solution here.
# # beeline -u 'jdbc:hive2://localhost:10000/olist_hive' -n "$USER" --silent=true -e "
# #   -- your HiveQL here
# # "

# %% [markdown]
# ## Exercise 6 — Seller performance by state
#
# For each seller state return distinct seller count, distinct order count, items sold, item revenue, and freight. Keep only states with at least 20 sellers.
#
# **Tip:** `HAVING` filters grouped states; `WHERE` filters input rows.

# %%
# %%bash
# # TODO: Write and run your solution here.
# # beeline -u 'jdbc:hive2://localhost:10000/olist_hive' -n "$USER" --silent=true -e "
# #   -- your HiveQL here
# # "

# %% [markdown]
# ## Exercise 7 — Delivery performance by customer state
#
# For delivered orders with both delivery dates present, calculate order count, average delivery days, average estimated days, and percentage delivered late for each customer state.
#
# **Tip:** Use `datediff(end_date, start_date)` and a conditional `AVG` or `SUM`/`COUNT`. Decide how exact timestamps compare for lateness.

# %%
# %%bash
# # TODO: Write and run your solution here.
# # beeline -u 'jdbc:hive2://localhost:10000/olist_hive' -n "$USER" --silent=true -e "
# #   -- your HiveQL here
# # "

# %% [markdown]
# ## Exercise 8 — Review score and revenue
#
# Return review score, distinct reviewed orders, average order payment, and total payment. Prevent duplicate review and payment rows from multiplying one another.
#
# **Tip:** This problem exposes two one-to-many relationships. Pre-aggregation would help, but this notebook bans subqueries/CTEs; explain the limitation and propose the safe query for the later CTE notebook.

# %%
# %%bash
# # TODO: Write and run your solution here.
# # beeline -u 'jdbc:hive2://localhost:10000/olist_hive' -n "$USER" --silent=true -e "
# #   -- your HiveQL here
# # "

# %% [markdown]
# ## Exercise 9 — Freight burden by category
#
# For each English product category, calculate item revenue, freight total, and freight as a percentage of `price + freight_value`. Keep categories with at least 500 item rows and show the 10 highest percentages.
#
# **Tip:** Protect division with `NULLIF` if supported; otherwise use a `CASE` expression around a zero denominator.

# %%
# %%bash
# # TODO: Write and run your solution here.
# # beeline -u 'jdbc:hive2://localhost:10000/olist_hive' -n "$USER" --silent=true -e "
# #   -- your HiveQL here
# # "

# %% [markdown]
# ## Exercise 10 — Customers served across seller states
#
# For every customer state, count distinct seller states and distinct sellers that supplied its orders. Return the broadest coverage first.
#
# **Tip:** Follow customers → orders → order items → sellers and count the requested entities, not join rows.

# %%
# %%bash
# # TODO: Write and run your solution here.
# # beeline -u 'jdbc:hive2://localhost:10000/olist_hive' -n "$USER" --silent=true -e "
# #   -- your HiveQL here
# # "

# %% [markdown]
# ## Final reflection
#
# Choose two queries and compare their Hive execution plans. Which stage performs the largest scan or shuffle? Which table could benefit from Parquet/ORC, partition pruning, or early aggregation? Do not recommend a MySQL-style B-tree index; explain the Hive mechanism instead.

# %%
# %%bash
# # TODO: Add EXPLAIN evidence and your reflection.
# # beeline -u 'jdbc:hive2://localhost:10000/olist_hive' -n "$USER" --silent=true -e "
# #   -- your HiveQL here
# # "
