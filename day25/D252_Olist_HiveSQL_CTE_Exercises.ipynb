# %% [markdown]
# # D252 — Olist HiveSQL CTE Exercises: Student Lab
#
# Every solution must use one or more common table expressions. These exercises assume D250 is complete. Do not use window functions and do not create permanent tables or views.

# %% [markdown]
# ## Lab conventions
#
# - Run this notebook from Jupyter in Ubuntu/WSL with HDFS, YARN, the Hive metastore, and HiveServer2 running.
# - Source CSVs are expected at `/mnt/c/data/olist`. Change `OLIST_SOURCE` if your copy is elsewhere.
# - Use database `olist_hive`. Raw external tables should be named after the MySQL tables: `olist_customers`, `olist_orders`, `olist_order_items`, `olist_order_payments`, `olist_order_reviews`, `olist_products`, `olist_sellers`, `olist_geolocation`, and `product_category_translation`.
# - These are learner exercises. TODO cells intentionally contain no completed answer.

# %% [markdown]
# ## MySQL → HiveSQL reminders
#
# | MySQL habit | HiveSQL approach in this lab |
# |---|---|
# | `LIMIT offset, count` | use `LIMIT count`; use `ROW_NUMBER()` when paging is genuinely required |
# | `IFNULL(x, y)` | prefer standard `COALESCE(x, y)` |
# | `DATEDIFF(end, start)` | same two-argument order in Hive; result is whole days |
# | `DATE_FORMAT(ts, '%Y-%m')` | use `date_format(ts, 'yyyy-MM')` |
# | `YEAR(ts)` / `MONTH(ts)` | `year(ts)` / `month(ts)` are available |
# | `GROUP_CONCAT` | use `concat_ws(',', collect_list(...))` when appropriate |
# | backtick-heavy identifiers | use simple lowercase snake_case names; backticks are rarely needed here |
# | primary keys, foreign keys, and row indexes | Hive generally does not enforce relational keys; performance comes from file format, partitions, statistics, pruning, and execution settings |
# | `EXPLAIN ANALYZE` | use `EXPLAIN`, `EXPLAIN FORMATTED`, and runtime/Tez or YARN evidence available in your installation |
#
# Hive aliases usually cannot be reused by another expression in the same `SELECT`. Put the first calculation in a CTE/subquery. Always make window ordering deterministic by adding an ID as a tie-breaker.

# %% [markdown]
# ## CTE notes for Hive
#
# A CTE exists only for the statement that follows its `WITH` clause. It is not a session-scoped temporary view and is not guaranteed to be materialized. Hive may inline or reorganize it. Use CTEs primarily for correct grain, readable stages, and avoiding accidental join multiplication. Use `EXPLAIN` to inspect the actual plan.

# %% [markdown]
# ## Exercise 1 — High-revenue sellers
#
# Create `seller_sales` at one row per seller with item count, distinct order count, and item revenue. Return sellers with revenue of at least 100,000.
#
# **Tip:** Filter the aggregate result in the outer query.

# %%
# %%bash
# # TODO: Write and run your solution here.
# # beeline -u 'jdbc:hive2://localhost:10000/olist_hive' -n "$USER" --silent=true -e "
# #   -- your HiveQL here
# # "

# %% [markdown]
# ## Exercise 2 — Seller performance with location
#
# Build a seller aggregate CTE, join it to sellers, and return the top 15 sellers with city, state, items sold, and revenue.
#
# **Tip:** Do not group by location until seller totals are correct.

# %%
# %%bash
# # TODO: Write and run your solution here.
# # beeline -u 'jdbc:hive2://localhost:10000/olist_hive' -n "$USER" --silent=true -e "
# #   -- your HiveQL here
# # "

# %% [markdown]
# ## Exercise 3 — Seller average compared with marketplace average
#
# Use one CTE for seller revenue and another for the marketplace average of those seller totals. Return sellers above the average.
#
# **Tip:** Hive supports multiple comma-separated CTE definitions after one `WITH`.

# %%
# %%bash
# # TODO: Write and run your solution here.
# # beeline -u 'jdbc:hive2://localhost:10000/olist_hive' -n "$USER" --silent=true -e "
# #   -- your HiveQL here
# # "

# %% [markdown]
# ## Exercise 4 — Monthly seller activity
#
# Create an order-level CTE that links purchase month and seller without double-counting a seller twice within the same order. Summarize active sellers and seller-order pairs by month.
#
# **Tip:** Use `SELECT DISTINCT` at the order–seller grain in the first stage.

# %%
# %%bash
# # TODO: Write and run your solution here.
# # beeline -u 'jdbc:hive2://localhost:10000/olist_hive' -n "$USER" --silent=true -e "
# #   -- your HiveQL here
# # "

# %% [markdown]
# ## Exercise 5 — Seller category concentration
#
# Build seller-category revenue, seller total revenue, and final percentage stages. Return sellers whose leading category supplies at least 80% of item revenue.
#
# **Tip:** Without windows, derive the maximum percentage per seller in another CTE and join it back; handle ties explicitly.

# %%
# %%bash
# # TODO: Write and run your solution here.
# # beeline -u 'jdbc:hive2://localhost:10000/olist_hive' -n "$USER" --silent=true -e "
# #   -- your HiveQL here
# # "

# %% [markdown]
# ## Exercise 6 — Seller customer-state reach
#
# Create distinct seller–customer-state pairs, count states per seller, and return the top 20 sellers by geographic reach with seller location.
#
# **Tip:** Deduplicate the pair before counting.

# %%
# %%bash
# # TODO: Write and run your solution here.
# # beeline -u 'jdbc:hive2://localhost:10000/olist_hive' -n "$USER" --silent=true -e "
# #   -- your HiveQL here
# # "

# %% [markdown]
# ## Exercise 7 — Safe review and payment analysis
#
# Pre-aggregate payments to one row per order and reviews to one row per order, then compare average payment across review-score groups.
#
# **Tip:** State how you combine multiple reviews for one order: average, maximum, latest, or another justified rule.

# %%
# %%bash
# # TODO: Write and run your solution here.
# # beeline -u 'jdbc:hive2://localhost:10000/olist_hive' -n "$USER" --silent=true -e "
# #   -- your HiveQL here
# # "

# %% [markdown]
# ## Exercise 8 — Order reconciliation
#
# Build item totals and payment totals separately at order grain. Join them to orders and classify each order as balanced, underpaid, or overpaid using a tolerance of 0.01.
#
# **Tip:** Hive aliases cannot reliably be reused in the same `SELECT`; calculate totals in earlier CTEs.

# %%
# %%bash
# # TODO: Write and run your solution here.
# # beeline -u 'jdbc:hive2://localhost:10000/olist_hive' -n "$USER" --silent=true -e "
# #   -- your HiveQL here
# # "

# %% [markdown]
# ## Exercise 9 — Repeat-buyer cohorts
#
# Derive each unique customer's first purchase month, then count customers and later orders by cohort month.
#
# **Tip:** Use an aggregate CTE for `MIN(order_purchase_timestamp)`; no window function is necessary.

# %%
# %%bash
# # TODO: Write and run your solution here.
# # beeline -u 'jdbc:hive2://localhost:10000/olist_hive' -n "$USER" --silent=true -e "
# #   -- your HiveQL here
# # "

# %% [markdown]
# ## Exercise 10 — Chained seller quality report
#
# Create chained CTEs for seller revenue, delivered-order timeliness, and review quality. Return sellers meeting thresholds you define for volume, on-time rate, and review score.
#
# **Tip:** Prevent fan-out by preparing one row per order or seller before joining measures.

# %%
# %%bash
# # TODO: Write and run your solution here.
# # beeline -u 'jdbc:hive2://localhost:10000/olist_hive' -n "$USER" --silent=true -e "
# #   -- your HiveQL here
# # "

# %% [markdown]
# ## Plan inspection
#
# Run `EXPLAIN` for Exercises 7 and 10. Identify each scan, aggregation, join, and shuffle. Explain whether the CTE boundaries appear as physical materialization boundaries in your Hive plan.

# %%
# %%bash
# # TODO: Add the two EXPLAIN statements and observations.
# # beeline -u 'jdbc:hive2://localhost:10000/olist_hive' -n "$USER" --silent=true -e "
# #   -- your HiveQL here
# # "
