# %% [markdown]
# # D093 — Practice Session 1
#
# ## Develop Data Processing Classes
#
# **Duration:** 60 minutes
# **Dataset:** MovieLens `ml-latest-small`
#
# Build a small object-oriented data pipeline that:
#
# 1. reads movie and rating records from CSV files
# 2. converts raw rows into `Movie` and `Rating` objects
# 3. displays useful object representations
# 4. writes processed records to JSON
#
# This is a student exercise. Complete every `TODO` and use the checkpoint cells to test your work.

# %% [markdown]
# ## Concepts practised
#
# - classes, objects, constructors, and `self`
# - instance methods and static methods
# - encapsulation with properties
# - inheritance and method overriding in the optional task
# - polymorphism through a common method interface
# - `__str__`, `__repr__`, and object equality
# - CSV reading, JSON writing, and type conversion
#
# ## Suggested time plan
#
# | Time | Task |
# |---|---|
# | 0–5 min | Inspect the input data |
# | 5–20 min | Build `Movie` and `Rating` |
# | 20–35 min | Build `CSVSourceReader` |
# | 35–45 min | Load and inspect objects |
# | 45–55 min | Build `JsonWriter` |
# | 55–60 min | Run the pipeline and verify output |
# | Optional | Base classes and polymorphic readers/writers |

# %% [markdown]
# # Dataset
#
# The MovieLens files used in this exercise are:
#
# ```text
# C:\data\movielens\ml-latest-small\movies\movies.csv
# C:\data\movielens\ml-latest-small\ratings\ratings.csv
# ```
#
# ### Movie columns
#
# | Column | Example | Required Python type |
# |---|---|---|
# | `movieId` | `1` | `int` |
# | `title` | `Toy Story (1995)` | `str` |
# | `genres` | `Adventure|Animation|Children` | `list[str]` |
#
# ### Rating columns
#
# | Column | Example | Required Python type |
# |---|---|---|
# | `userId` | `1` | `int` |
# | `movieId` | `1` | `int` |
# | `rating` | `4.0` | `float` |
# | `timestamp` | `964982703` | `int` |

# %%
from pathlib import Path


MOVIES_PATH = Path(
    r"C:\data\movielens\ml-latest-small\movies\movies.csv"
)
RATINGS_PATH = Path(
    r"C:\data\movielens\ml-latest-small\ratings\ratings.csv"
)
OUTPUT_PATH = Path("output") / "ratings_sample.json"

print("Movies file exists:", MOVIES_PATH.exists())
print("Ratings file exists:", RATINGS_PATH.exists())

# %% [markdown]
# # Task 1 — Inspect the source files (5 minutes)
#
# Read only the first three lines from each file. Confirm the delimiter, headers, and genre separator before designing the classes.
#
# Use a context manager so the file is closed automatically.

# %%
# TODO 1: Print the first three lines from MOVIES_PATH.
# TODO 2: Print the first three lines from RATINGS_PATH.
# Hint: open(path, encoding="utf-8") and next(file_object)

# Write your code below.

# %% [markdown]
# # Task 2 — Create the domain classes (15 minutes)
#
# ## 2A. `Movie`
#
# Create a `Movie` class with:
#
# - constructor parameters `movie_id`, `title`, and `genres`
# - `movie_id` stored as an `int`
# - `title` stored as a `str`
# - `genres` stored as a list of strings
# - a read-only `release_year` property extracted from the final `(YYYY)` in the title
# - `__str__` returning a readable movie description
# - `__repr__` returning valid constructor-style Python code
# - `__eq__` comparing movies by `movie_id`
# - `to_dict()` returning JSON-compatible data
#
# The constructor should accept genres either as a pipe-separated string or as a list. This makes both CSV construction and `repr` reconstruction possible.
#
# Example representations:
#
# ```text
# str(movie)  -> Toy Story (1995) [Adventure, Animation, Children, Comedy, Fantasy]
# repr(movie) -> Movie(movie_id=1, title='Toy Story (1995)', genres=['Adventure', ...])
# ```

# %%
class Movie:
    def __init__(self, movie_id, title, genres):
        # TODO: Convert and store all three values.
        # If genres is a string, split it using "|".
        pass

    @property
    def release_year(self):
        # TODO: Return the final four-digit year as int.
        # Return None when the title has no final (YYYY).
        pass

    def __str__(self):
        # TODO: Return friendly, readable text.
        pass

    def __repr__(self):
        # TODO: Return constructor-style code.
        # Use !r for strings and the genres list.
        pass

    def __eq__(self, other):
        # TODO: Return NotImplemented for an unrelated type.
        # Otherwise compare movie_id values.
        pass

    def to_dict(self):
        # TODO: Return a dictionary with snake_case keys.
        pass

# %% [markdown]
# ### Movie checkpoint
#
# Uncomment and run after completing `Movie`. Every assertion should pass.

# %%
# movie = Movie(
#     movie_id="1",
#     title="Toy Story (1995)",
#     genres="Adventure|Animation|Children|Comedy|Fantasy",
# )
#
# print(movie)
# print(repr(movie))
#
# assert movie.movie_id == 1
# assert movie.release_year == 1995
# assert movie.genres[0] == "Adventure"
# assert movie == Movie(1, "Different title", [])
# assert eval(repr(movie), {"Movie": Movie}) == movie
# assert movie.to_dict()["movie_id"] == 1
# print("Movie checkpoint passed")

# %% [markdown]
# ## 2B. `Rating`
#
# Create a `Rating` class with:
#
# - constructor parameters `user_id`, `movie_id`, `rating`, and `timestamp`
# - IDs and timestamp stored as `int`
# - rating stored as `float`
# - an encapsulated `rating` property that accepts only values from `0.0` to `5.0`
# - a read-only `rated_at` property converting the Unix timestamp to a `datetime`
# - `__str__`, reconstructible `__repr__`, and `to_dict()`
#
# For JSON output, `to_dict()` should store `rated_at` as an ISO-formatted string, for example `2000-07-30T...`.

# %%
from datetime import datetime, timezone


class Rating:
    def __init__(self, user_id, movie_id, rating, timestamp):
        # TODO: Convert and store IDs and timestamp.
        # Assign through self.rating so the setter validates it.
        pass

    @property
    def rating(self):
        # TODO: Return the internal rating value.
        pass

    @rating.setter
    def rating(self, value):
        # TODO: Convert value to float.
        # Raise ValueError unless 0.0 <= value <= 5.0.
        pass

    @property
    def rated_at(self):
        # TODO: Convert the Unix timestamp to a UTC datetime.
        # Hint: datetime.fromtimestamp(..., tz=timezone.utc)
        pass

    def __str__(self):
        # TODO: Return friendly text containing user, movie, and rating.
        pass

    def __repr__(self):
        # TODO: Return a reconstructible Rating(...) expression.
        pass

    def to_dict(self):
        # TODO: Return JSON-compatible data with rated_at in ISO format.
        pass

# %% [markdown]
# ### Rating checkpoint
#
# Uncomment and run after completing `Rating`.

# %%
# rating = Rating(user_id="1", movie_id="1", rating="4.0", timestamp="964982703")
#
# print(rating)
# print(repr(rating))
# print(rating.rated_at)
#
# assert rating.user_id == 1
# assert rating.movie_id == 1
# assert rating.rating == 4.0
# rebuilt_rating = eval(repr(rating), {"Rating": Rating})
# assert rebuilt_rating.to_dict() == rating.to_dict()
#
# try:
#     Rating(1, 1, 7.0, 964982703)
#     raise AssertionError("An invalid rating was accepted")
# except ValueError:
#     print("Invalid rating correctly rejected")
#
# print("Rating checkpoint passed")

# %% [markdown]
# # Task 3 — Create `CSVSourceReader` (15 minutes)
#
# Build one reusable CSV reader instead of separate movie and rating readers.
#
# The class must:
#
# - accept a source path in its constructor
# - expose the path through a read-only `path` property
# - reject a missing path with `FileNotFoundError`
# - read rows using `csv.DictReader`
# - accept a `row_factory` callable that converts each dictionary into an object
# - support an optional `limit` so tests do not have to load the entire file
# - return a list of constructed objects
#
# Examples of row factories:
#
# ```python
# lambda row: Movie(row["movieId"], row["title"], row["genres"])
# lambda row: Rating(row["userId"], row["movieId"], row["rating"], row["timestamp"])
# ```

# %%
import csv


class CSVSourceReader:
    def __init__(self, path):
        # TODO: Convert path to pathlib.Path and store it internally.
        # TODO: Raise FileNotFoundError when it is not a file.
        pass

    @property
    def path(self):
        # TODO: Return the stored path.
        pass

    def read(self, row_factory, limit=None):
        # TODO: Open with newline="" and encoding="utf-8".
        # TODO: Iterate over csv.DictReader.
        # TODO: Convert each row with row_factory and append it.
        # TODO: Stop after limit objects when limit is not None.
        # TODO: Return the list.
        pass

# %% [markdown]
# ### CSV reader checkpoint (10 minutes)
#
# Create small factory functions rather than placing long lambdas inside the pipeline. Then load five movies and five ratings.
#
# Uncomment after completing the classes.

# %%
def movie_from_row(row):
    """Convert one DictReader movie row into a Movie."""
    # TODO: Return a Movie constructed from the CSV column names.
    pass


def rating_from_row(row):
    """Convert one DictReader rating row into a Rating."""
    # TODO: Return a Rating constructed from the CSV column names.
    pass


# movie_reader = CSVSourceReader(MOVIES_PATH)
# rating_reader = CSVSourceReader(RATINGS_PATH)
#
# movies = movie_reader.read(movie_from_row, limit=5)
# ratings = rating_reader.read(rating_from_row, limit=5)
#
# for movie in movies:
#     print(repr(movie))
#
# for rating in ratings:
#     print(repr(rating))
#
# assert len(movies) == 5
# assert len(ratings) == 5
# assert all(isinstance(movie, Movie) for movie in movies)
# assert all(isinstance(rating, Rating) for rating in ratings)
# print("CSV reader checkpoint passed")

# %% [markdown]
# # Task 4 — Create `JsonWriter` (10 minutes)
#
# Build a writer that converts objects to dictionaries and writes a JSON array.
#
# The class must:
#
# - accept an output path in its constructor
# - create the parent output directory when required
# - provide `write(records)`
# - call `record.to_dict()` for each object
# - write formatted UTF-8 JSON using an indentation of 2
# - return the number of written records
#
# Use `ensure_ascii=False` so Unicode text is preserved.

# %%
import json


class JsonWriter:
    def __init__(self, path):
        # TODO: Convert and store path as pathlib.Path.
        pass

    @property
    def path(self):
        # TODO: Return the output path.
        pass

    def write(self, records):
        # TODO: Create the parent directory with parents=True.
        # TODO: Convert each record by calling to_dict().
        # TODO: Write the list using json.dump(..., indent=2,
        #       ensure_ascii=False).
        # TODO: Return the number of records written.
        pass

# %% [markdown]
# # Task 5 — Run the complete pipeline (5 minutes)
#
# Load the first 100 ratings and write them to `OUTPUT_PATH`. Read the JSON file back and verify its structure.
#
# Uncomment after all required classes are complete.

# %%
# rating_reader = CSVSourceReader(RATINGS_PATH)
# ratings = rating_reader.read(rating_from_row, limit=100)
#
# writer = JsonWriter(OUTPUT_PATH)
# written_count = writer.write(ratings)
#
# with OUTPUT_PATH.open(encoding="utf-8") as file:
#     saved_ratings = json.load(file)
#
# print("Records written:", written_count)
# print("Output path:", OUTPUT_PATH.resolve())
# print("First saved record:", saved_ratings[0])
#
# assert written_count == 100
# assert len(saved_ratings) == 100
# assert saved_ratings[0]["user_id"] == 1
# assert isinstance(saved_ratings[0]["rated_at"], str)
# print("Pipeline checkpoint passed")

# %% [markdown]
# # Required completion checklist
#
# - [ ] `Movie` converts raw values to appropriate Python types.
# - [ ] `Movie.release_year` is a read-only computed property.
# - [ ] `Movie.__repr__` can reconstruct an equivalent movie.
# - [ ] `Rating.rating` validates the range `0.0` to `5.0`.
# - [ ] `Rating.rated_at` returns a timezone-aware UTC `datetime`.
# - [ ] `CSVSourceReader` works for both files without duplicated reader code.
# - [ ] The reader's `limit` works correctly.
# - [ ] `JsonWriter` creates its output directory.
# - [ ] The JSON file contains 100 rating dictionaries.
# - [ ] Class names use `PascalCase`; methods and variables use `snake_case`.

# %% [markdown]
# # Optional challenge A — Join ratings with movie titles
#
# **Suggested additional time:** 10–15 minutes
#
# 1. Load all movies.
# 2. Create a dictionary mapping `movie_id` to `Movie`.
# 3. Load the first 100 ratings.
# 4. Produce dictionaries containing `user_id`, `movie_id`, `title`, `rating`, and `rated_at`.
# 5. Write the enriched data to `output/enriched_ratings.json`.
#
# Do not use a nested loop to find a movie for every rating. Dictionary lookup keeps the join simple and efficient.

# %%
# TODO (optional): Implement the in-memory join.

# all_movies = ...
# movies_by_id = ...
# sample_ratings = ...
# enriched_ratings = ...

# %% [markdown]
# # Optional challenge B — Reader and writer base classes
#
# **Suggested additional time:** 10 minutes
#
# `csv.reader` and `csv.DictReader` are parsing tools, not public base classes for an application-level reader. `io.TextIOBase` represents a raw text stream, while `CSVSourceReader` produces domain objects. Inheriting from either would model the wrong relationship.
#
# Instead, create small application-level base classes:
#
# ```python
# class SourceReader:
#     def read(self, row_factory, limit=None):
#         raise NotImplementedError
#
#
# class DataWriter:
#     def write(self, records):
#         raise NotImplementedError
# ```
#
# Then:
#
# 1. make `CSVSourceReader` inherit from `SourceReader`
# 2. make `JsonWriter` inherit from `DataWriter`
# 3. override the required method in each derived class
# 4. write `run_pipeline(reader, writer, row_factory, limit)` that works through the common interfaces
#
# This demonstrates inheritance and polymorphism without pretending that a structured data reader is a raw file stream.

# %%
# TODO (optional): Refactor the completed classes to use these base classes.

class SourceReader:
    def read(self, row_factory, limit=None):
        raise NotImplementedError


class DataWriter:
    def write(self, records):
        raise NotImplementedError


# TODO: Define the derived classes or update your earlier classes.
# TODO: Implement run_pipeline(...).

# %% [markdown]
# # Reflection
#
# Answer briefly after completing the exercise:
#
# 1. Why should type conversion happen when a row becomes an object?
# 2. Why is one reusable `CSVSourceReader` preferable to duplicated movie and rating readers?
# 3. How does the `rating` property protect object state?
# 4. Why should `__repr__` include every constructor value?
# 5. Why is `CSVSourceReader` not a suitable subclass of `io.TextIOBase`?
# 6. Which parts of this pipeline could be reused for another CSV dataset?
